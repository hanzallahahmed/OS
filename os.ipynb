# %%
import subprocess
import threading
import os

class simpOS:
    def __init__(self):
        self.processes = []
        self.main_menue()
        self.Backup()
        self.processManagement()
        self.serviceManagement()
        self.userManagement()

    def main_menu(self):
        print("---------Main Menu----------")
        print("1. User Management")
        print("2. Service Management")
        print("3. Process Management")
        print("4. Backup ")
        choice = int(input("Enter your Choice [1-4] : "))
        #based on choice it will start further operations

        if choice == 1:
            self.userManagement()
        
        if choice == 2:
            self.serviceManagement()

        if choice == 3:
            self.processManagement()
        
        else:
            self.Backup()

    
    def userManagement(self):
        try:
            print("----------------------------------------")
            print("Welcome to User Management ")
            print("1. Create User")
            print("2. Modify User")
            print("3. Delete User")
            print("4. Change Password")
            print("5. Go back to Main Menu")
            opt = int(input("Enter your Choice [1-5] : "))
            #based on choice it will start further operations

            # if opt == 1:
            #     self.CreateUser()
            
            # if opt == 2:
            #     self.ModifyUser()

            # if opt == 3:
            #     self.DeleteUser()
            
            # if opt == 4:
            #     self.ChangePass()

            if opt == 5:
                self.main_menue()

        except:
            print("Enter between option 1-5 : ")


    def serviceManagement(self):
        try:
            print("----------------------------------------")
            print("1. Program execution")
            print("2. I/O operations")
            print("3. File System manipulation")
            print("4. Communication")
            print("5. Resource Allocation")
            print("6. Go back to Main Menu")
            ser = int(input("Enter your Choice [1-6] : "))

            if ser == 1:
                self.ProExe()
            
            if ser == 2:
                io = IOClass()
            
            if ser == 3:
                fs = FSClass()

            if ser == 4:
                commu = CommuClass()

            if ser == 5:
                resAllo = ResAllClass()
            
            elif ser == 6:
                self.main_menue()

        except:
            print("Enter between Services 1-6 : ")

    def processManagement(self):
        print("----------------------------------------")
        print("1. List Running Processes")
        print("2. Terminate Process")
        print("3. Priority Management")
        print("4. View Process Information")
        print("5. Resource Usage Monitoring")
        pro = int(input("Enter Your choice[1 - 5]: "))

        if pro==5:
            self.main_menue()


    def Backup(self):
        try:
            print("\n")
            print("----------------------------------------")
            print("1. Make backup in existing folder")
            print("2. Create new folder and make backup there")
            ch = int(input("Enter Your choice[1 - 3]: "))
            if ch==1:
                print("Making Backup......")
            if ch==2:
                print("Creating Folder........")

            elif ch == 3:
                    self.main_menue()
        except:
            print("Enter between Options 1 - 3 : ")

class IOClass(simpOS):
    def __init__(self):
        print("I/O....")

class FSClass(simpOS):
    def __init__(self):
        print("Manipulatin Files....")
    
class CommuClass(simpOS):
    def __init__(self):
        print("Communicating....")
    
class ResAllClass(simpOS):
    def __init__(self):
        print("Allocating Resources....")
    


if __name__ == "__main__":
    os_simulator = simpOS()
    os_simulator.main_menue()
    os_simulator.processManagement()
    os_simulator.serviceManagement()
    os_simulator.userManagement
    os_simulator.Backup()
